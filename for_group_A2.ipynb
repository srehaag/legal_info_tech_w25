# %% [markdown]
# <a href="https://colab.research.google.com/github/srehaag/legal_info_tech_w25/blob/main/for_group_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q

# %%
# Test the accuracy of the system generally
questions_and_answers = [
    {
      "question": "What types of works qualify for copyright protection in Canada?",
      "A": "Copyright protects original literary, dramatic, musical, and artistic works, including books, poems, scripts, paintings, photographs, films, and songs.",
      "B": "Copyright protects original literary, dramatic, musical, and artistic works, including books, poems, paintings, photographs, and songs.",
      "C": "Copyright protects art work.",
      "D": "Copyright protects inventions.",
      "answer": "A"
    },
    {
      "question": "What makes a work ‘original’ for copyright purposes?",
      "A": "A work must be independently created.",
      "B": "A work must be collaboratively created.",
      "C": "A work must be independently created with some level of skill and judgment to be considered original.",
      "D": "A work must be collaboratively created with some level of skill and judgment to be considered original.",
      "answer": "C"
    }
]
# for the purposes of efficiency, I cannot currently test the system using all of the questions (or, rather, if I were to do so, it would take a very long time for the code to run).
# This is because the system message, which contains the token-heavy variables, is passed to OpenAI separately for each row.
# Because of the 30000 token per minute limit, it would take a very long time to run the test using all of the questions.
# Again, this issue is largely because I am a tier 1 organization

additional_questions_and_answers = [
    {
      "question": "Can I copyright my ideas?",
      "A": "Yes, copyright protects unexpressed ideas.",
      "B": "No, copyright only protects the expression of ideas, not the ideas themselves.",
      "C": "Yes, copyright protects everything.",
      "D": "No, copyright only protects inventions.",
      "answer": "B",
    },
    {
      "question": "Does copyright protect my work internationally?",
      "A": "Yes, Canada is part of international treaties that provide copyright protection in many countries.",
      "B": "No, Canadian copyright only applies domestically.",
      "C": "Yes, but only if you register your work in each country.",
      "D": "No, copyright laws vary too much between countries.",
      "answer": "A"
    },
    {
      "question": "If I share my work online, do I still own the copyright?",
      "A": "Yes, posting your work online does not change your copyright ownership.",
      "B": "No, once something is online, anyone can use it freely.",
      "C": "Yes, but only if you include a copyright notice.",
      "D": "No, websites automatically claim copyright over posted content.",
      "answer": "A"
    },
    {
      "question": "Can I sell or transfer my copyright to someone else?",
      "A": "Yes, copyright can be sold, transferred, or licensed through a written agreement.",
      "B": "No, copyright always remains with the original creator.",
      "C": "Yes, but only if the government approves the transfer.",
      "D": "No, copyright is non-transferable under Canadian law.",
      "answer": "A"
    },
    {
      "question": "How long does copyright last in Canada?",
      "A": "Copyright lasts for the life of the author plus 70 years after their death.",
      "B": "Copyright lasts forever.",
      "C": "Copyright lasts for 50 years after publication.",
      "D": "Copyright expires 10 years after creation.",
      "answer": "A"
    },
    {
      "question": "Who owns the copyright if I create something for my job?",
      "A": "If created as part of employment, the employer usually owns the copyright unless otherwise agreed.",
      "B": "The employee always retains copyright, regardless of the job.",
      "C": "Copyright is shared equally between the employee and employer.",
      "D": "Copyright laws do not apply to work created for a job.",
      "answer": "A"
    },
    {
      "question": "Can I use copyrighted material without permission?",
      "A": "Yes, under fair dealing for purposes like research, education, and news reporting.",
      "B": "No, you must always get permission for any use.",
      "C": "Yes, but only for commercial purposes.",
      "D": "No, unless the work is over 100 years old.",
      "answer": "A"
    },
    {
      "question": "How does fair dealing apply to educational use?",
      "A": "Educational institutions can use copyrighted works under fair dealing provisions, as clarified in case law.",
      "B": "Schools must always pay royalties to use copyrighted materials.",
      "C": "Students can use any copyrighted work freely for assignments.",
      "D": "Fair dealing does not apply to education in Canada.",
      "answer": "A"
    },
    {
      "question": "What does copyright protect in terms of reproducing artwork?",
      "A": "Copyright protects an artist’s right to control reproductions of their work.",
      "B": "Anyone can freely reproduce an artist’s work after purchase.",
      "C": "Only digital copies of artwork are protected under copyright.",
      "D": "Copyright does not apply to visual arts.",
      "answer": "A"
    },
    {
      "question": "If I use a small portion of a copyrighted work, is that okay?",
      "A": "It depends on whether the use qualifies as fair dealing.",
      "B": "Yes, small portions of any work can be used freely.",
      "C": "No, all copyrighted content requires permission.",
      "D": "Yes, as long as you don’t make money from it.",
      "answer": "A"
    },
    {
      "question": "Can I use a copyrighted image for my social media post?",
      "A": "Using a copyrighted image without permission may infringe on copyright, unless it qualifies as fair dealing.",
      "B": "Yes, social media use is always exempt from copyright laws.",
      "C": "No, all images online are copyrighted.",
      "D": "Yes, as long as you credit the creator.",
      "answer": "A"
    },
    {
      "question": "Does copyright protect logos and brand names?",
      "A": "No, logos and brand names are protected under trademark law, not copyright law.",
      "B": "Yes, logos and brand names are protected under copyright.",
      "C": "Yes, but only if registered with the Copyright Office.",
      "D": "No, logos and brand names have no legal protection.",
      "answer": "A"
    },
    {
      "question": "Does copyright apply to self-published works?",
      "A": "Yes, self-published works receive the same copyright protection as traditionally published works.",
      "B": "No, only books published by major publishers get copyright protection.",
      "C": "Yes, but only if you register the copyright.",
      "D": "No, self-published works are automatically public domain.",
      "answer": "A"
    },
    {
      "question": "Can I copyright a recipe or a list of ingredients?",
      "A": "A simple list of ingredients cannot be copyrighted, but an original expression of a recipe may qualify.",
      "B": "Yes, all recipes are copyrighted.",
      "C": "No, recipes are never protected under copyright.",
      "D": "Only recipes published in cookbooks can be copyrighted.",
      "answer": "A"
    },
    {
      "question": "If I modify an existing work, do I own the copyright?",
      "A": "You may hold copyright over your modifications, but the original creator still retains rights over their portion of the work.",
      "B": "Yes, modifying any work gives you full copyright ownership.",
      "C": "No, modified works are still entirely owned by the original creator.",
      "D": "Yes, but only if the changes are minimal.",
      "answer": "A"
    },
    {
      "question": "Are government publications protected by copyright?",
      "A": "Yes, but many Canadian government works are published under an open license that allows free use.",
      "B": "No, all government publications are public domain.",
      "C": "Yes, and they cannot be reproduced under any circumstances.",
      "D": "No, copyright does not apply to official documents.",
      "answer": "A"
    },
    {
      "question": "What is the benefit of registration?",
      "A": "It allows you to sell your work internationally without restrictions.",
      "B": "It grants you copyright protection that does not exist otherwise.",
      "C": "It automatically extends your copyright beyond the standard term.",
      "D": "The Copyright Act states that a certificate of registration of copyright is evidence that the copyright subsists and that the person registered is the owner of the copyright.",
      "answer": "D"
    },
    {
      "question": "Why should I register my copyright?",
      "A": "Registration is required to have any legal rights to your work.",
      "B": "It is the only way to prevent others from using your work.",
      "C": "Without registration, copyright protection expires after 5 years.",
      "D": "Generally, your original work is automatically protected by copyright when you create it. However, when you register your copyright, you get a certificate of registration that you can use in court as evidence that you own the protected work.",
      "answer": "D"
    },
    {
      "question": "Do I need to register my copyright?",
      "A": "Yes, all works must be registered to be protected under copyright law.",
      "B": "Only works published in Canada require registration.",
      "C": "Registration is required for copyright protection to apply internationally.",
      "D": "No, a work is protected by copyright law the moment it is created and fixed in a material form. Registering your work with CIPO is voluntary, but can be beneficial. The certificate of registration is evidence that copyright subsists in the work and that the person registered is the owner of the copyright.",
      "answer": "D"
    },
    {
      "question": "Is registration mandatory for copyright?",
      "A": "Yes, every copyrighted work must be registered with CIPO.",
      "B": "Only books and films require registration.",
      "C": "Copyright registration is only required if you plan to sue someone for infringement.",
      "D": "No, a work is protected by copyright law the moment it is created and fixed in a material form. Registering your work with CIPO is voluntary, but can be beneficial.",
      "answer": "D"
    },
    {
      "question": "How can I register my copyright?",
      "A": "By publishing your work in any recognized Canadian publication.",
      "B": "By mailing a copy of your work to yourself as proof of ownership.",
      "C": "To register your copyright you must file an application accompanied by the appropriate fee with CIPO, a federal agency responsible for the administration and processing of IP rights in Canada, including the registration of copyrights. You can file your application for copyright registration with CIPO electronically, by mail or by fax.",
      "D": "By obtaining a notarized document declaring ownership of your work.",
      "answer": "C"
    },
    {
      "question": "How do I register an assigned copyright?",
      "A": "Assignments cannot be registered, only original works can be.",
      "B": "To register an assignment, a copy of the original transfer agreement or a photocopy signed by both parties must be filed with CIPO along with the prescribed fee. You must also include the names or the registration numbers of the affected works. Requests may be submitted by mail, by fax or online.",
      "C": "You need to publish a notice in a legal journal stating the assignment.",
      "D": "Assignments are automatically registered upon agreement between parties.",
      "answer": "B"
    },
    {
      "question": "If a copyright was assigned to me, how do I register it?",
      "A": "Assignments do not need to be registered, but you may voluntarily register by submitting a copy of the original transfer agreement or a photocopy signed by both parties must be filed with CIPO along with the prescribed fee. You must also include the names or the registration numbers of the affected works. Requests may be submitted by mail, by fax or online.",
      "B": "The copyright is automatically transferred in CIPO’s records upon assignment.",
      "C": "You must apply for a new copyright entirely.",
      "D": "Assignments expire unless registered within 30 days.",
      "answer": "A"
    },
    {
      "question": "If a copyright was assigned to me, do I need to register it?",
      "A": "Yes, all copyright assignments must be registered to be valid.",
      "B": "No, a work is protected by copyright law the moment it is created and fixed in a material form. Registration is voluntary but can be beneficial.",
      "C": "Only assignments of literary works require registration.",
      "D": "Assignment registration is only required if the work is used commercially.",
      "answer": "B"
    },
    {
      "question": "Who can I contact if I have a question about registering my copyright?",
      "A": "CIPO's Client Service Centre",
      "B": "The Canadian Supreme Court.",
      "C": "The Canadian Revenue Agency.",
      "D": "Your local public library.",
      "answer": "A"
    },
    {
      "question": "How much does it cost to register a copyright?",
      "A": "Registration is free for all artists.",
      "B": "Different fees must be paid at various times during the copyright application process. A full list is available from CIPO.",
      "C": "A fixed fee of $500 applies to all registrations.",
      "D": "There is no cost associated with copyright registration in Canada.",
      "answer": "B"
    },
    {
      "question": "What is the cost for the registration of a copyright assignment?",
      "A": "$200 CAD.",
      "B": "There is no fee for assignment registration.",
      "C": "$81 CAD.",
      "D": "$50 CAD plus an additional annual maintenance fee.",
      "answer": "C"
    },
    {
      "question": "Is the owner the only person able to register a Copyright in Works?",
      "A": "Yes, only the original creator of the work may register a copyright.",
      "B": "No. Application for the registration of a copyright in a work may be made by or on behalf of the author of the work, the owner of the copyright in the work, an assignee of the copyright, or a person to whom an interest in the copyright has been granted by licence.",
      "C": "Only corporations can register copyrights in Canada.",
      "D": "A copyright can only be registered by a legal professional on behalf of the owner.",
      "answer": "B"
    },
    {
      "question": "Is the owner the only person able to register a Copyright in subject-matter other than Works?",
      "A": "Yes, copyright registration is only available to original authors.",
      "B": "No. Application for the registration of a copyright in subject-matter other than a work may be made by or on behalf of the owner of the copyright in the subject-matter, an assignee of the copyright, or a person to whom an interest in the copyright has been granted by licence.",
      "C": "Only a government body can register copyright in subject-matter other than works.",
      "D": "Copyright registration is only available for literary and artistic works.",
      "answer": "B"
    }
]

# %%
import pandas as pd
df_questions_and_answers = pd.DataFrame(additional_questions_and_answers)

df_questions_only = df_questions_and_answers.copy().drop(columns = ["answer"])

df_questions_only
# Out:
#                                              question  \
# 0                           Can I copyright my ideas?
# 1     Does copyright protect my work internationally?
# 2   If I share my work online, do I still own the ...
# 3   Can I sell or transfer my copyright to someone...
# 4             How long does copyright last in Canada?
# 5   Who owns the copyright if I create something f...
# 6   Can I use copyrighted material without permiss...
# 7     How does fair dealing apply to educational use?
# 8   What does copyright protect in terms of reprod...
# 9   If I use a small portion of a copyrighted work...
# 10  Can I use a copyrighted image for my social me...
# 11      Does copyright protect logos and brand names?
# 12      Does copyright apply to self-published works?
# 13  Can I copyright a recipe or a list of ingredie...
# 14  If I modify an existing work, do I own the cop...
# 15  Are government publications protected by copyr...
# ...

# %%
import json

from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

from openai import OpenAI

client = OpenAI()

def get_completion(user_message,
        system_message,
        model = "gpt-4o",
        temperature = 0.5):

    # print("MESSAGE CONFIRMATION:" + "USER MESSAGE: " + user_message + "SYSTEM MESSAGE: " + system_message + "Model: " + model + "Temperature: " + str(temperature))

    completion = client.chat.completions.create(
        model=model,
        temperature=temperature,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": user_message}
        ]
    )
    return completion.choices[0].message.content

def ai_test(row):
  user_message = row.to_json()
  # The row.to_json() and the user message was suggested by generative AI after I received an error in my initial code.
  system_message_3 = f"""The user message will be a JSON representation of a pandas dataframe row. The 'question' key contains a question. Other keys ('A', 'B', 'C,' and 'D') contain potential answers. Answer the question by returning only the key with the correct answer. Do not use quotation marks. """
  return get_completion(user_message, system_message_3)

# %%
df_questions_and_answers["AI_answer"] = df_questions_only.apply(ai_test, axis = 1)

df_questions_and_answers
# Out:
#                                              question  \
# 0                           Can I copyright my ideas?
# 1     Does copyright protect my work internationally?
# 2   If I share my work online, do I still own the ...
# 3   Can I sell or transfer my copyright to someone...
# 4             How long does copyright last in Canada?
# 5   Who owns the copyright if I create something f...
# 6   Can I use copyrighted material without permiss...
# 7     How does fair dealing apply to educational use?
# 8   What does copyright protect in terms of reprod...
# 9   If I use a small portion of a copyrighted work...
# 10  Can I use a copyrighted image for my social me...
# 11      Does copyright protect logos and brand names?
# 12      Does copyright apply to self-published works?
# 13  Can I copyright a recipe or a list of ingredie...
# 14  If I modify an existing work, do I own the cop...
# 15  Are government publications protected by copyr...
# ...
